# %% [markdown]
# # Приоритезация гипотез и A/B тест для интернет-магазина "Контест"

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Приоритезация-гипотез-и-A/B-тест-для-интернет-магазина-&quot;Контест&quot;" data-toc-modified-id="Приоритезация-гипотез-и-A/B-тест-для-интернет-магазина-&quot;Контест&quot;-1">Приоритезация гипотез и A/B тест для интернет-магазина "Контест"</a></span><ul class="toc-item"><li><span><a href="#План-работ:" data-toc-modified-id="План-работ:-1.1">План работ:</a></span><ul class="toc-item"><li><span><a href="#Часть-1:" data-toc-modified-id="Часть-1:-1.1.1">Часть 1:</a></span></li><li><span><a href="#Часть-2:" data-toc-modified-id="Часть-2:-1.1.2">Часть 2:</a></span></li></ul></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2">Описание данных</a></span><ul class="toc-item"><li><span><a href="#Данные-для-первой-части" data-toc-modified-id="Данные-для-первой-части-1.2.1">Данные для первой части</a></span></li><li><span><a href="#Данные-для-второй-части" data-toc-modified-id="Данные-для-второй-части-1.2.2">Данные для второй части</a></span></li></ul></li><li><span><a href="#Импорт-библиотек,-обзор-датасета" data-toc-modified-id="Импорт-библиотек,-обзор-датасета-1.3">Импорт библиотек, обзор датасета</a></span></li><li><span><a href="#Фреймворк-ICE-для-приоритизации-гипотез." data-toc-modified-id="Фреймворк-ICE-для-приоритизации-гипотез.-1.4">Фреймворк ICE для приоритизации гипотез.</a></span></li><li><span><a href="#Фреймворк-RICE-для-приоритизации-гипотез." data-toc-modified-id="Фреймворк-RICE-для-приоритизации-гипотез.-1.5">Фреймворк RICE для приоритизации гипотез.</a></span></li><li><span><a href="#Часть-2.-Анализ-A/B-теста" data-toc-modified-id="Часть-2.-Анализ-A/B-теста-1.6">Часть 2. Анализ A/B-теста</a></span><ul class="toc-item"><li><span><a href="#Общие-сведения-о-датасетах" data-toc-modified-id="Общие-сведения-о-датасетах-1.6.1">Общие сведения о датасетах</a></span></li><li><span><a href="#Проверка-на-пропуски" data-toc-modified-id="Проверка-на-пропуски-1.6.2">Проверка на пропуски</a></span></li><li><span><a href="#Проверка-на-дубликаты" data-toc-modified-id="Проверка-на-дубликаты-1.6.3">Проверка на дубликаты</a></span></li><li><span><a href="#Изменение-типа-даты" data-toc-modified-id="Изменение-типа-даты-1.6.4">Изменение типа даты</a></span></li><li><span><a href="#Изучение-данных-перед-проведением-A/B-теста:" data-toc-modified-id="Изучение-данных-перед-проведением-A/B-теста:-1.6.5">Изучение данных перед проведением A/B-теста:</a></span></li><li><span><a href="#График-кумулятивной-выручки-по-группам" data-toc-modified-id="График-кумулятивной-выручки-по-группам-1.6.6">График кумулятивной выручки по группам</a></span></li><li><span><a href="#График-кумулятивного-среднего-чека-по-группам" data-toc-modified-id="График-кумулятивного-среднего-чека-по-группам-1.6.7">График кумулятивного среднего чека по группам</a></span></li><li><span><a href="#График-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A" data-toc-modified-id="График-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A-1.6.8">График относительного изменения кумулятивного среднего чека группы B к группе A</a></span></li><li><span><a href="#График-кумулятивной-конверсии-по-группам" data-toc-modified-id="График-кумулятивной-конверсии-по-группам-1.6.9">График кумулятивной конверсии по группам</a></span></li><li><span><a href="#График-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A." data-toc-modified-id="График-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A.-1.6.10">График относительного изменения кумулятивной конверсии группы B к группе A.</a></span></li><li><span><a href="#Точечный-график-количества-заказов-по-пользователям." data-toc-modified-id="Точечный-график-количества-заказов-по-пользователям.-1.6.11">Точечный график количества заказов по пользователям.</a></span></li><li><span><a href="#95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Граница-для-определения-аномальных-пользователей." data-toc-modified-id="95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Граница-для-определения-аномальных-пользователей.-1.6.12">95-й и 99-й перцентили количества заказов на пользователя. Граница для определения аномальных пользователей.</a></span></li><li><span><a href="#Точечный-график-стоимостей-заказов" data-toc-modified-id="Точечный-график-стоимостей-заказов-1.6.13">Точечный график стоимостей заказов</a></span></li><li><span><a href="#95-й-и-99-й-перцентили-стоимости-заказов-на-пользователя.-Граница-для-определения-аномальных-пользователей." data-toc-modified-id="95-й-и-99-й-перцентили-стоимости-заказов-на-пользователя.-Граница-для-определения-аномальных-пользователей.-1.6.14">95-й и 99-й перцентили стоимости заказов на пользователя. Граница для определения аномальных пользователей.</a></span></li><li><span><a href="#Cтатистическая-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным." data-toc-modified-id="Cтатистическая-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным.-1.6.15">Cтатистическая значимость различий в конверсии между группами по «сырым» данным.</a></span></li><li><span><a href="#Cтатистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным" data-toc-modified-id="Cтатистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным-1.6.16">Cтатистическая значимость различий в среднем чеке заказа между группами по «сырым» данным</a></span></li><li><span><a href="#Статистическая-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным" data-toc-modified-id="Статистическая-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным-1.6.17">Статистическая значимость различий в конверсии между группами по «очищенным» данным</a></span></li><li><span><a href="#Cтатистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным" data-toc-modified-id="Cтатистическая-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным-1.6.18">Cтатистическая значимость различий в среднем чеке заказа между группами по «очищенным» данным</a></span></li></ul></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-1.7">Вывод:</a></span></li><li><span><a href="#Проделанные-работы:" data-toc-modified-id="Проделанные-работы:-1.8">Проделанные работы:</a></span><ul class="toc-item"><li><span><a href="#Часть-1:" data-toc-modified-id="Часть-1:-1.8.1">Часть 1:</a></span></li><li><span><a href="#Часть-2:" data-toc-modified-id="Часть-2:-1.8.2">Часть 2:</a></span></li><li><span><a href="#Решение-по-результатам-теста" data-toc-modified-id="Решение-по-результатам-теста-1.8.3">Решение по результатам теста</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# Вместе с отделом маркетинга был подготовлен список гипотез для увеличения выручки в интернет-магазине "Контекст".
# Нужно приоритезировать  гипотезы, запустить A/B-тест и проанализировать результат.
#
# ## План работ:
#
# ### Часть 1:
#
# Работа с гипотезами:
#
# - Применить фреймворк ICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# - Применить фреймворк RICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# - Указать,  как изменилась приоритизация гипотез при применении RICE вместо ICE.
#
# ### Часть 2:
#
# Проанализировать A/B-тест:
#
# - Построить график кумулятивной выручки по группам. Сделать выводы и предположения.
# - Построить график кумулятивного среднего чека по группам. Сделать выводы и предположения.
# - Построить график относительного изменения кумулятивного среднего чека группы B к группе A. Сделать выводы и предположения.
# - Построить график кумулятивной конверсии по группам. Сделать выводы и предположения.
# - Построить график относительного изменения кумулятивной конверсии группы B к группе A. Сделать выводы и предположения.
# - Построить точечный график количества заказов по пользователям. Сделать выводы и предположения.
# - Посчитать 95-й и 99-й перцентили количества заказов на пользователя. Выбрать границу для определения аномальных пользователей.
# - Построить точечный график стоимостей заказов. Сделать выводы и предположения.
# - Посчитать 95-й и 99-й перцентили стоимости заказов. Выбрать границу для определения аномальных заказов.
# - Посчитать статистическую значимость различий в конверсии между группами по «сырым» данным. Сделать выводы и предположения.
# - Посчитать статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделать выводы и предположения.
# - Посчитать статистическую значимость различий в конверсии между группами по «очищенным» данным. Сделать выводы и предположения.
# - Посчитать статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделать выводы и предположения.
# - Принять решение по результатам теста и объяснить его.

# %% [markdown]
# ## Описание данных
# ### Данные для первой части
# Датасет 'hypothesis':
#
# Hypothesis — краткое описание гипотезы;
# Reach — охват пользователей по 10-балльной шкале;
# Impact — влияние на пользователей по 10-балльной шкале;
# Confidence — уверенность в гипотезе по 10-балльной шкале;
# Efforts — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
# ### Данные для второй части
# Датасет 'orders':
#
# transactionId — идентификатор заказа;
# visitorId — идентификатор пользователя, совершившего заказ;
# date — дата, когда был совершён заказ;
# revenue — выручка заказа;
# group — группа A/B-теста, в которую попал заказ.
#
# Датасет 'visitors':
#
# date — дата;
# group — группа A/B-теста;
# visitors — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# ## Импорт библиотек, обзор датасета

# %% [markdown]
# Импортируем библиотеки, которые понадобятся для работы по проекту:

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import scipy.stats as stats
import datetime as dt

import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from matplotlib.pyplot import figure

import warnings

# %%
data = pd.read_csv('/datasets/hypothesis.csv')

# %% [markdown]
# Выведем первые 10 строк файла с гипотезами.
# Каждая гипотеза оценена по шкале от 1 до 10 по четырем параметрам - Reach, Impact, Confidence, Efforts:

# %%
pd.options.display.max_colwidth = 120
data.head(10)
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# ##  Фреймворк ICE для приоритизации гипотез.

# %% [markdown]
# ICE (от англ. impact, confidence, effort / ease «влияние, уверенность, усилия / простота») — один из самых популярных способов приоритизации задач.
#
# Состоит из трех компонентов:
#
# Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# Efforts — сколько стоит протестировать эту гипотезу.
#
# Приоритетизация расcчитывается по формуле:
#
# ICE Score = (Impact * Confidence) / Efforts

# %%
data['ICE'] = (data['Impact'] * data['Confidence']) / data['Efforts']
pd.options.display.max_colwidth = 120
print (data[['Hypothesis', 'ICE']].sort_values(by='ICE', ascending=False))
# Out:
#                                                                                                      Hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# Если выстраивать приоритизацию по ICE, приоритетными оказываются гипотезы 8, 0, 7.

# %% [markdown]
# ## Фреймворк RICE для приоритизации гипотез.

# %% [markdown]
# Фреймворк RICE состоит из четырёх компонентов:
#
# Reach — скольких пользователей затронет изменение, которое вы хотите внести;
# Impact — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
# Confidence — насколько вы уверены, что это изменение повлияет на пользователей именно так;
# Efforts — сколько стоит протестировать эту гипотезу.
#
# Рассчитывается по формуле:
#
# RICE Score = (Reach * Impact * Confidence) / Efforts

# %%
data['RICE'] = (data['Reach'] * data['Impact'] * data['Confidence']) / data['Efforts']
pd.options.display.max_colwidth = 120
print (data[['Hypothesis', 'RICE']].sort_values(by='RICE', ascending=False))
# Out:
#                                                                                                      Hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# При использовании фактора RICE добавился фактор Reach, поэтому приоритезация изменилась и приоритетными стали гипотезы 7, 2, 0. Например, у гипотезы 7 фактор Reach оценивался в 10 баллов, поэтому при приоритезации по методу RICE гипотеза заняла первое место.
#
# Фактор Reach  поменял приоритеты, так как важными стали гипотезы с высоким баллом по фактору Reach, то есть охватывающие большое количество пользователей.
#
# Например, гипотеза 7 'Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок' при воплощении коснется всех пользователей сайта единовременно, в то время как гипотеза 8  'Запустить акцию, дающую скидку на товар в день рождения' действует избирательно, т.к. скидка применима только к покупателям, у которых в данный момент день рождения. В отличие от ICE, фреймворк RICE приоритезирует гипотезы с широким охватом клиентов.

# %% [markdown]
# ## Часть 2. Анализ A/B-теста

# %% [markdown]
# ### Общие сведения о датасетах

# %% [markdown]
# Загрузим файлы:

# %%
orders = pd.read_csv('/datasets/orders.csv')
visitors = pd.read_csv('/datasets/visitors.csv')

# %% [markdown]
# Выведем первые 5 строк каждого датасета:

# %%
orders.head(5)
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B

# %% [markdown]
# Для удобства переименуем столбцы:

# %%
orders.columns = ['transaction_id', 'visitor_id', 'date', 'revenue', 'group']
orders.head(5)
# Out:
#    transaction_id  visitor_id        date  revenue group
# 0      3667963787  3312258926  2019-08-15     1650     B
# 1      2804400009  3642806036  2019-08-15      730     B
# 2      2961555356  4069496402  2019-08-15      400     A
# 3      3797467345  1196621759  2019-08-15     9759     B
# 4      2282983706  2322279887  2019-08-15     2308     B

# %% [markdown]
# Выведем первые 5 строк второго датасета:

# %%
visitors.head(5)
# Out:
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756

# %% [markdown]
# ### Проверка на пропуски

# %% [markdown]
# Убедимся, что пропусков в датасетах нет:

# %%
datasets = [orders, visitors]
for i in datasets:
    print(i.isna().sum())
# Out:
# transaction_id    0
# visitor_id        0
# date              0
# revenue           0
# group             0
# dtype: int64
# date        0
# group       0
# visitors    0
# dtype: int64

# %% [markdown]
# ### Проверка на дубликаты

# %% [markdown]
# Убедимся, что дубликатов нет:

# %%
datasets = [orders, visitors]
for i in datasets:
    print(i.duplicated().sum())
# Out:
# 0
# 0

# %% [markdown]
# ### Изменение типа даты

# %% [markdown]
# C помощью функции изменим тип данных с датами:

# %%
datasets = [orders['date'], visitors['date']]
for i in datasets:
    i.map(
    lambda x: dt.datetime.strptime(x, '%Y-%m-%d')
)

# %% [markdown]
# ### Изучение данных перед проведением A/B-теста:

# %% [markdown]
# Убедимся, что в обоих датасетах только две группы - A и B:

# %%
datasets = [orders, visitors]
for i in datasets:
    print(i['group'].unique())
# Out:
# ['B' 'A']
# ['A' 'B']

# %% [markdown]
# Даты начала и окончания теста одинаковы в обоих датасетах:

# %%
datasets = [orders, visitors]
for i in datasets:
    print(i['date'].min())
    print(i['date'].max())
# Out:
# 2019-08-01
# 2019-08-31
# 2019-08-01
# 2019-08-31

# %% [markdown]
# Видно, что группы неодинаковые, в группе B на 83 заказа больше:

# %%
print (orders.loc[orders['group'] == "A", 'visitor_id'].count())
print (orders.loc[orders['group'] == "B", 'visitor_id'].count())
# Out:
# 557
# 640

# %% [markdown]
# Проверим пересечения двух списков. Видно, что в группах есть одни и те же пользователи:

# %%
visitors_a = orders.loc[orders['group'] == "A", 'visitor_id']
visitors_b = orders.loc[orders['group'] == "B", 'visitor_id']   
visitors_both_groups = list(set(visitors_a) & set(visitors_b))
print (visitors_both_groups)
# Out:
# [3957174400, 3984495233, 2780786433, 1294878855, 1648269707, 1614305549, 4120364173, 232979603, 199603092, 4266935830, 2712142231, 2587333274, 2716752286, 3891541246, 1668030113, 2654030115, 3234906277, 1230306981, 1404934699, 3803269165, 2949041841, 237748145, 457167155, 2927087541, 1738359350, 3062433592, 3656415546, 818047933, 393266494, 963407295, 471551937, 2579882178, 3202540741, 2686716486, 1333886533, 2044997962, 3941795274, 1801183820, 2378935119, 4256040402, 4069496402, 3766097110, 8300375, 351125977, 1602967004, 276558944, 2038680547, 3951559397, 3963646447, 4186807279, 3717692402, 1959144690, 2458001652, 2600415354, 2954449915, 1316129916, 477780734, 3972127743]

# %% [markdown]
# Всего таких уникальных пользователей 58:

# %%
print (len(visitors_both_groups))
# Out:
# 58

# %% [markdown]
# Проверим один из ID - '199603092':

# %%
print (orders.query('visitor_id == 199603092'))
# Out:
#       transaction_id  visitor_id        date  revenue group
# 26        2223239646   199603092  2019-08-15     3488     A
# 134         62794304   199603092  2019-08-22     6976     A
# 246        437656952   199603092  2019-08-02     3488     B
# 823       2971973105   199603092  2019-08-27     2790     A
# 1102      1941707234   199603092  2019-08-12     6438     A

# %% [markdown]
# Видно, что пользователь сделал 5 заказов, из них 4 в группе A и 1 в группе B:

# %% [markdown]
# Удалим пользователей, вошедших в обе группы, из теста:

# %%
orders = orders.query('visitor_id != @visitors_both_groups')

# %% [markdown]
# Проверим, находится ли еще постетитель с ID '199603092' в датасете:

# %%
print (orders.query('visitor_id == 199603092'))
# Out:
# Empty DataFrame
# Columns: [transaction_id, visitor_id, date, revenue, group]
# Index: []

# %% [markdown]
# Получаем пустой датасет.
#
# Проверим, сколько пользователей осталось в группах после удаления:

# %%
print (orders.loc[orders['group'] == "A", 'visitor_id'].count())
print (orders.loc[orders['group'] == "B", 'visitor_id'].count())
# Out:
# 468
# 548

# %% [markdown]
# Группы A и B сократились на 92 и 89 покупателей соответственно.

# %% [markdown]
# ### График кумулятивной выручки по группам

# %% [markdown]
# Построим график кумулятивной выручки по группам:

# %%
# создаем массив уникальных пар значений дат и групп теста
dates_groups = orders[['date','group']].drop_duplicates()

# получаем агрегированные кумулятивные по дням данные о заказах 
orders_aggregated = dates_groups.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'],
orders['group'] == x['group'])].agg(
{'date' : 'max', 'group' : 'max', 'transaction_id' : 'nunique', 'visitor_id' : 'nunique', 'revenue' : 'sum'}), axis=1
                                      ).sort_values(by=['date','group'])

# получаем агрегированные кумулятивные по дням данные о посетителях интернет-магазина 
visitors_aggregated = dates_groups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], 
visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1
                                        ).sort_values(by=['date','group'])

# объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
cumulative_data = orders_aggregated.merge(visitors_aggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulative_data.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

print(cumulative_data.tail(5))
# Out:
#           date group  orders  buyers  revenue  visitors
# 57  2019-08-29     B     510     490  4746610     17708
# 58  2019-08-30     A     460     437  3311413     18037
# 59  2019-08-30     B     531     511  4955833     18198
# 60  2019-08-31     A     468     445  3364656     18736
# 61  2019-08-31     B     548     528  5068972     18916

# %% [markdown]
# Разобьем датасет на группы и построим график:

# %%
cumulative_revenue_a = cumulative_data[cumulative_data['group']=='A'][['date','revenue', 'orders']]
cumulative_revenue_b = cumulative_data[cumulative_data['group']=='B'][['date','revenue', 'orders']]

figure(figsize=(8, 6))
plt.plot(cumulative_revenue_a['date'], cumulative_revenue_a['revenue'], label='A')
plt.plot(cumulative_revenue_b['date'], cumulative_revenue_b['revenue'], label='B')

plt.ylabel("Выручка")
plt.title ('График кумулятивной выручки по группам')
plt.xticks(rotation=90)
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)
plt.legend();

# %% [markdown]
# В первые две недели выручка обеих групп была сопоставима, но затем кумулятивная выручка группы B начала обгонять группу A, и к концу периода разрыв составил почти 2 млн. рублей.
# Резкий рост выручки группы B наблюдается 19 августа - возможно, в этот день был очень дорогой заказ или всплеск числа заказов.

# %% [markdown]
# ### График кумулятивного среднего чека по группам

# %% [markdown]
# Построим графики среднего чека по группам. Для этого разделим кумулятивную выручку на кумулятивное число заказов:

# %%
figure(figsize=(8, 6))
plt.plot(cumulative_revenue_a['date'], cumulative_revenue_a['revenue']/cumulative_revenue_a['orders'], label='A')
plt.plot(cumulative_revenue_b['date'], cumulative_revenue_b['revenue']/cumulative_revenue_b['orders'], label='B')
plt.xticks(rotation=90)
plt.ylabel("Средний чек")
plt.title ('График среднего чека по группам')
plt.legend();

# %% [markdown]
# Средний чек для группы A установился на уровне 7000 после резкого уменьшения в начала теста.
# Для группы B средний чек резко возрос 19 августа. Возможно, в этот день были сделаны крупные заказы. После 19 августа средний чек в группе B снизился, но разрыв с группой A на конец периода составил около 2000 рублей в пользу группы B.

# %% [markdown]
# ### График относительного изменения кумулятивного среднего чека группы B к группе A

# %% [markdown]
# Построим график относительного изменения кумулятивного среднего чека группы B к группе A:

# %%
# собираем данные в одном датафрейме
merged_cumulative_revenue = cumulative_revenue_a.merge(
    cumulative_revenue_b, left_on='date', right_on='date', how='left', suffixes=['_a', '_b'])


# cтроим отношение средних чеков
figure(figsize=(8, 6))

plt.plot(merged_cumulative_revenue['date'], (
    merged_cumulative_revenue['revenue_b']/merged_cumulative_revenue['orders_b'])/(
    merged_cumulative_revenue['revenue_a']/merged_cumulative_revenue['orders_a'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--')


plt.xticks(rotation=90)
plt.ylabel("Средний чек")
plt.title ('График относительного изменения кумулятивного среднего чека по группам' + '\n');

# %% [markdown]
# Видны большие различия между группами A и B в пользу группы B. Возможно, причиной резких различий между группами стали крупные покупки или всплески активности покупателей группы B.

# %% [markdown]
# ### График кумулятивной конверсии по группам

# %% [markdown]
# Рассчитаем кумулятивную конверсию, разделив кумулятивное количество покупателей на кумулятивное количество посетителей:

# %%
cumulative_data['conversion'] = cumulative_data['buyers'] / cumulative_data['visitors'] * 100

print(cumulative_data.tail(5))
# Out:
#           date group  orders  buyers  revenue  visitors  conversion
# 57  2019-08-29     B     510     490  4746610     17708    2.767111
# 58  2019-08-30     A     460     437  3311413     18037    2.422798
# 59  2019-08-30     B     531     511  4955833     18198    2.808001
# 60  2019-08-31     A     468     445  3364656     18736    2.375107
# 61  2019-08-31     B     548     528  5068972     18916    2.791288

# %% [markdown]
# Разобьем датасет на группы и построим график:

# %%
cumulative_conversion_a = cumulative_data[cumulative_data['group']=='A'][['date','conversion']]
cumulative_conversion_b = cumulative_data[cumulative_data['group']=='B'][['date', 'conversion']]

figure(figsize=(8, 6))
plt.plot(cumulative_conversion_a['date'], cumulative_conversion_a['conversion'], label='A')
plt.plot(cumulative_conversion_b['date'], cumulative_conversion_b['conversion'], label='B')

plt.ylabel("Конверсия")
plt.title ('График кумулятивной конверсии по группам')
plt.xticks(rotation=90)

plt.legend()
plt.axis(["2019-08-01", '2019-08-31', 0, 5]);

# %% [markdown]
# После резких колебаний в начале теста, группа B перегнала по кумулятивной конверсии группу A. Обе группы зафиксировались на своих уровнях, группа B опережает групппу A на протяжении практически всего теста.

# %% [markdown]
# ### График относительного изменения кумулятивной конверсии группы B к группе A.

# %% [markdown]
# Объединим датасеты групп A и B с кумулятивными конверсиями:

# %%
merged_cumulative_conversion = cumulative_conversion_a.merge(
    cumulative_conversion_b, left_on='date', right_on='date', how='left', suffixes=['_a', '_b'])
merged_cumulative_conversion.head(5)
# Out:
#          date  conversion_a  conversion_b
# 0  2019-08-01      2.642559      2.384292
# 1  2019-08-02      2.690583      3.013910
# 2  2019-08-03      3.252033      2.939545
# 3  2019-08-04      2.771272      2.565099
# 4  2019-08-05      2.772755      2.652439

# %% [markdown]
# Построим график относительного изменения кумулятивной конверсии двух групп:

# %%
# cтроим отношение конверсий
figure(figsize=(8, 6))

plt.plot(
    merged_cumulative_conversion['date'], ((
        merged_cumulative_conversion['conversion_b']/merged_cumulative_conversion['conversion_a'])-1)
)

# добавляем ось X
plt.axhline(y=0.1, color='black', linestyle='dotted')
plt.axhline(y=0, color='black', linestyle='--')


plt.xticks(rotation=90)
plt.ylabel("Относительная конверсия")
plt.title ('График относительного изменения кумулятивной конверсии группы B к группе A' + '\n');

# %% [markdown]
# Группа B после 6 августа стабильно лучше группы A по кумулятивной конверсии. За все время теста был только короткий период 3-5 августа, когда кумулятивная конверсия группы B была хуже. На протяжении почти всего теста конверсия группы B была на 10% выше.

# %% [markdown]
# ### Точечный график количества заказов по пользователям.

# %% [markdown]
# Для построения графика количества заказов на пользователя сгруппируем датасет 'orders' по группам и по visitor_id. Используем функцию agg для подсчета количества заказов на каждого пользователя:

# %%
orders_by_user = orders.groupby(['visitor_id', 'group']).agg({'transaction_id' : 'nunique'}).reset_index()

orders_by_user.head(5)
# Out:
#    visitor_id group  transaction_id
# 0     5114589     B               1
# 1     6958315     B               1
# 2    11685486     A               1
# 3    39475350     B               1
# 4    47206413     B               1

# %% [markdown]
# Построим точечный график с разбивкой по группам:

# %%
plt.figure(figsize=(13,5))
sns.set_style("whitegrid")
x_values = pd.Series(range(0,len(orders_by_user['transaction_id'])))
sns.scatterplot(x=x_values, y=orders_by_user['transaction_id'], hue=orders_by_user['group'])
plt.title( 'Точечный график количества заказов по группам и пользователям', fontsize=20)
plt.ylabel('Количество заказов');

# %% [markdown]
# Видно, что чаще всего на пользователя приходится один заказ, реже - 2-3 заказа.  В целом, распределение количества заказов между группами достаточно равномерное, скорее всего, разница между группами объясняется именно разницей стоимости заказов, а не количества заказов.

# %% [markdown]
# ###  95-й и 99-й перцентили количества заказов на пользователя. Граница для определения аномальных пользователей.

# %% [markdown]
# Построим гистрограмму распределения количества заказов. Видно, что почти все пользователи совершают один заказ:

# %%
plt.figure(figsize=(13,5))
orders_by_user['transaction_id'].hist()
plt.title( 'Гистограмма распределения количества заказов по группам и пользователям', fontsize=20)
plt.ylabel('Количество заказов');

# %% [markdown]
# Подсчитаем 95-й и 99-й перцентили количества заказов:

# %%
print(np.percentile(orders_by_user['transaction_id'], [95, 99]))
# Out:
# [1. 2.]

# %% [markdown]
# Большая часть пользователей делает один заказ, только 5% пользователей совершают более одного заказа, и 1% пользователей - больше 2 заказов.
# Выберем 99й перцентиль как границу для определения аномальных пользователей.

# %% [markdown]
# ### Точечный график стоимостей заказов

# %% [markdown]
# Построим точечный график стоимостей заказов:

# %%
plt.figure(figsize=(13,5))
sns.set_style("whitegrid")
x_values = pd.Series(range(0,len(orders['revenue'])))
sns.scatterplot(x=x_values, y=orders['revenue'], hue=orders['group'])
plt.title( 'Точечный график стоимостей заказов по группам и пользователям', fontsize=20)
plt.ylabel('Стоиомость заказов')
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False);

# %% [markdown]
# Тот же самый график без выброса:

# %%
orders_without_extreme_values =  orders.query('revenue < 1000000')
plt.figure(figsize=(13,5))
sns.set_style("whitegrid")
x_values = pd.Series(range(0,len(orders_without_extreme_values['revenue'])))
sns.scatterplot(x=x_values, y=orders_without_extreme_values['revenue'], hue=orders['group'])
plt.title( 'Точечный график стоимостей заказов по группам и пользователям без выброса', fontsize=20)
plt.ylabel('Стоиомость заказов')
plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False);

# %% [markdown]
# На графике видно, что все заказы, кроме одного из группы B, попадают в диапазон 0-200000. Один очень дорогой заказ был в группе B - более 1 200 000 руб. Второй самый дорогой заказ был также в группе B - около 200 000 руб.
#
# Проверим эти данные в датасете. Данные подтверждаются, два самых дорогих заказы были сделаны в группе B:

# %%
orders.sort_values(by='revenue', ascending=False).head(5)
# Out:
#       transaction_id  visitor_id        date  revenue group
# 425        590470918  1920142716  2019-08-19  1294500     B
# 1196      3936777065  2108080724  2019-08-15   202740     B
# 1136       666610489  1307669133  2019-08-13    92550     A
# 744       3668308183   888512513  2019-08-27    86620     B
# 743       3603576309  4133034833  2019-08-09    67990     A

# %% [markdown]
# ### 95-й и 99-й перцентили стоимости заказов на пользователя. Граница для определения аномальных пользователей.

# %% [markdown]
# Подсчитаем перцентили стоимости заказов:

# %%
print(np.percentile(orders['revenue'], [95, 99]))
# Out:
# [26785. 53904.]

# %% [markdown]
# Менее 5% посетителей заказали на сумму от 26785 руб., и менее 1% - на сумму от 53904 руб.
# Возьмем 95-й перцентиль как границу для определения аномальных пользователей.

# %% [markdown]
# ### Cтатистическая значимость различий в конверсии между группами по «сырым» данным.

# %% [markdown]
# Соберем датасет 'data' с общими и кумулятивными показателями по заказам, доходам, посетителям:

# %%
visitors_a_daily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitors_a_daily.columns = ['date', 'visitors_per_date_a']

visitors_a_cummulative = visitors_a_daily.apply(
    lambda x: visitors_a_daily[visitors_a_daily['date'] <= x['date']].agg(
        {'date': 'max', 'visitors_per_date_a': 'sum'}
    ),
    axis=1,
)
visitors_a_cummulative.columns = ['date', 'visitors_a_cummulative']



visitors_b_daily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitors_b_daily.columns = ['date', 'visitors_per_date_b']

visitors_b_cummulative = visitors_b_daily.apply(
    lambda x: visitors_b_daily[visitors_b_daily['date'] <= x['date']].agg(
        {'date': 'max', 'visitors_per_date_b': 'sum'}
    ),
    axis=1,
)
visitors_b_cummulative.columns = ['date', 'visitors_b_cummulative']



orders_a_daily = (
    orders[orders['group'] == 'A'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
orders_a_daily.columns = ['date', 'orders_per_date_a', 'revenue_per_date_a']

orders_a_cummulative = orders_a_daily.apply(
    lambda x: orders_a_daily[orders_a_daily['date'] <= x['date']].agg(
        {'date': 'max', 'orders_per_date_a': 'sum', 'revenue_per_date_a': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])


orders_a_cummulative.columns = [
    'date',
    'orders_cummulative_a',
    'revenue_cummulative_a',
]


orders_b_daily = (
    orders[orders['group'] == 'B'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
orders_b_daily.columns = ['date', 'orders_per_date_b', 'revenue_per_date_b']

orders_b_cummulative = orders_b_daily.apply(
    lambda x: orders_b_daily[orders_b_daily['date'] <= x['date']].agg(
        {'date': 'max', 'orders_per_date_b': 'sum', 'revenue_per_date_b': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
orders_b_cummulative.columns = [
    'date',
    'orders_cummulative_b',
    'revenue_cummulative_b',
]


data = (
    orders_a_daily.merge(
        orders_b_daily, left_on='date', right_on='date', how='left'
    )
    .merge(orders_a_cummulative, left_on='date', right_on='date', how='left')
    .merge(orders_b_cummulative, left_on='date', right_on='date', how='left')
    .merge(visitors_a_daily, left_on='date', right_on='date', how='left')
    .merge(visitors_b_daily, left_on='date', right_on='date', how='left')
    .merge(visitors_a_cummulative, left_on='date', right_on='date', how='left')
    .merge(visitors_b_cummulative, left_on='date', right_on='date', how='left')
)

display(data.head(5))
# Out:
#          date  orders_per_date_a  revenue_per_date_a  orders_per_date_b  \
# 0  2019-08-01                 23              142779                 17
# 1  2019-08-02                 19               91602                 23
# 2  2019-08-03                 24              112473                 14
# 3  2019-08-04                 11               41176                 14
# 4  2019-08-05                 22               86383                 21
#
#    revenue_per_date_b  orders_cummulative_a  revenue_cummulative_a  \
# 0               59758                    23                 142779
# 1              162043                    42                 234381
# 2               67049                    66                 346854
# 3               96890                    77                 388030
# 4               89908                    99                 474413
#
#    orders_cummulative_b  revenue_cummulative_b  visitors_per_date_a  \
# ...

# %% [markdown]
# Для расчета конверсии, используем соотношение покупатели/посетители для каждой группы.
#
# Аггрегируем датасет с заказами по посетителям и тразакциям, для каждой группы.
# Получаем список количества транзакций на каждого клиента:

# %%
orders_by_user_a = (
    orders[orders['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
orders_by_user_a.columns = ['visitor_id', 'orders']

orders_by_user_b = (
    orders[orders['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
orders_by_user_b.columns = ['visitor_id', 'orders']

# %%
orders_by_user_a.head(5)
# Out:
#    visitor_id  orders
# 0    11685486       1
# 1    54447517       1
# 2    66685450       1
# 3    78758296       1
# 4    85103373       1

# %% [markdown]
# Создадим sample A и sample B, где у посетителей, не совершавших покупки, в количестве заказов будет стоять 0:

# %%
sample_a = pd.concat(
    [orders_by_user_a['orders'],pd.Series(
        0, index=np.arange(data['visitors_per_date_a'].sum() - len(orders_by_user_a['orders'])), name='orders')],axis=0)

sample_b = pd.concat(
    [orders_by_user_b['orders'],pd.Series(
        0, index=np.arange(data['visitors_per_date_b'].sum() - len(orders_by_user_b['orders'])), name='orders')],axis=0)

# %% [markdown]
# Видим, что 0 успешно внесены в список:

# %%
sample_a.tail(5)
# Out:
# 18286    0
# 18287    0
# 18288    0
# 18289    0
# 18290    0
# Name: orders, dtype: int64

# %% [markdown]
# Сформулируем нулевую и альтернативную гипотезы:
#
# Нулевая гипотеза: между группами A и B нет статистически значимых различий в конверсии
# Альтернативная гипотеза:  между группами A и B есть статистически значимые различия в конверсии
#
# Уровень значимости alpha = 0.05
#
# Выведем на экран p-value, рассчитанный по тесту Манна-Уитни, и соотношение двух конверсий (группы B к группе A):

# %%
print("{0:.3f}".format(stats.mannwhitneyu(sample_a, sample_b)[1]))

print("{0:.3f}".format(sample_b.mean() / sample_a.mean() - 1))
# Out:
# 0.011
# 0.160

# %% [markdown]
# Вывод: по «сырым» данным различия в конверсии групп A и B есть.
# P-value = 0.011, меньше alpha (0.05). Значит, нулевую гипотезу о том, что статистически значимых различий по конверсии между группами нет, отвергаем.
# Относительный проигрыш группы A равен 16% — второе число в выводе.

# %% [markdown]
#  ### Cтатистическая значимость различий в среднем чеке заказа между группами по «сырым» данным

# %% [markdown]
# Сформулируем нулевую и альтернативную гипотезы:
#
# Нулевая гипотеза: между группами A и B нет статистически значимых различий в среднем чеке
# Альтернативная гипотеза:  между группами A и B есть статистически значимые различия в среднем чеке
#
# Уровень значимости alpha = 0.05
#
#
# Выведем на экран p-value, рассчитанный по тесту Манна-Уитни, и соотношение двух средних чеков (группы B к группе A):

# %%
print('{0:.3f}'.format(
    stats.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])[1]))

print('{0:.3f}'.format(
    orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# 0.829
# 0.287

# %% [markdown]
# Вывод: по «сырым» данным различий в среднем чеке групп A и B нет.
# P-value = 0.829, больше 0.05. Значит, нулевую гипотезу о том, что статистически значимых различий по среднем чеку между группами нет, не отвергаем.
# Во второй строчке кода рассчитано соотношение среднего чека между группами: относительный выигрыш группы B равен 28.7%.
#
# Вероятно, в группе B большие выбросы по стоимости заказов, которые тест Манна-Уитни нивелировал.

# %% [markdown]
# ### Статистическая значимость различий в конверсии между группами по «очищенным» данным

# %% [markdown]
# Примем за аномальных пользователей тех, кто совершил от 2 заказов или совершил заказ дороже 26 875 рублей (примем за границу аномальных пользователей 95-й перцентиль для стоимости заказа и 99-й перцентиль - для количества заказов). Так мы уберём 1% пользователей с наибольшим числом заказов и 5% пользователей с дорогими заказами.
#
# Сделаем срезы пользователей с числом заказов больше 2 — users_with_many_orders и пользователей, совершивших заказы дороже 26 875 — users_with_expensive_orders. Объединим их в таблице abnormal_users.
#
# Узнаем, сколько всего аномальных пользователей атрибутом shape:

# %%
users_with_many_orders = pd.concat(
    [
        orders_by_user_a[orders_by_user_a['orders'] > float(np.percentile(
            orders_by_user['transaction_id'], [99]))]['visitor_id'],
        
        orders_by_user_b[orders_by_user_b['orders'] > float(np.percentile(
            orders_by_user['transaction_id'], [99]))]['visitor_id']], axis=0)



users_with_expensive_orders = orders[orders['revenue'] > float(np.percentile(
            orders['revenue'], [95]))]['visitor_id']


abnormal_users = (
    pd.concat([users_with_many_orders, users_with_expensive_orders], axis=0)
    .drop_duplicates()
    .sort_values()
)

print(abnormal_users.head(5))
print(abnormal_users.shape[0])
# Out:
# 568     113298937
# 1099    148427295
# 928     204675465
# 33      249864742
# 684     358944393
# Name: visitor_id, dtype: int64
# 58

# %% [markdown]
# Всего таких пользователей 58.

# %% [markdown]
# Пересчитаем конверсию, не включая abnormal users:

# %%
conversion_a = (
    orders[np.logical_and(orders['group'] == 'A', np.logical_not(
        orders['visitor_id'].isin(abnormal_users)))]
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.count})
)

conversion_b = (
      orders[np.logical_and(orders['group'] == 'B', np.logical_not(
        orders['visitor_id'].isin(abnormal_users)))]
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id' : pd.Series.count})
)

# %% [markdown]
# Создадим sample A и sample B, где у посетителей, не совершавших покупки, в количестве заказов будет стоять 0:

# %%
sample_a = pd.concat(
    [conversion_a['transaction_id'],pd.Series(
        0, index=np.arange(data['visitors_per_date_a'].sum() - len(
            conversion_a['transaction_id'])), name='transaction_id')],axis=0)

sample_b = pd.concat(
    [conversion_b['transaction_id'],pd.Series(
        0, index=np.arange(data['visitors_per_date_b'].sum() - len(
            conversion_b['transaction_id'])), name='transaction_id')],axis=0)

# %% [markdown]
# Сформулируем нулевую и альтернативную гипотезы:
#
# Нулевая гипотеза: между группами A и B нет статистически значимых различий в конверсии
# Альтернативная гипотеза:  между группами A и B есть статистически значимые различия в конверсии
#
# Уровень значимости alpha = 0.05
#
# Выведем на экран p-value, рассчитанный по тесту Манна-Уитни, и соотношение двух средних конверсий (группы B к группе A):

# %%
print("{0:.3f}".format(stats.mannwhitneyu(sample_a, sample_b)[1]))

print("{0:.3f}".format(sample_b.mean() / sample_a.mean() - 1))
# Out:
# 0.012
# 0.182

# %% [markdown]
# P-value равен 0.012, что меньше 0.05, поэтому можно отвергнуть нулевую гипотезу, которая гласит, что конверсии между группами не отличаются.
# Группа B опередила группу A на 18% по уровню конверсии.
#
# По очищенным данным, выигрыш группы B по конверсии еще более очевиден.

# %% [markdown]
# ### Cтатистическая значимость различий в среднем чеке заказа между группами по «очищенным» данным

# %% [markdown]
# Выполним тест Манна-Уитни по очищенным данным. Проверим различия между группами по среднему чеку.
#
# Сформулируем нулевую и альтернативную гипотезы:
#
# Нулевая гипотеза: между группами A и B нет статистически значимых различий в среднем чеке
# Альтернативная гипотеза:  между группами A и B есть статистически значимые различия в среднем чеке
#
# Уровень значимости alpha = 0.05
#
# Выведем на экран p-value, рассчитанный по тесту Манна-Уитни, и соотношение двух средних чеков (группы B к группе A):

# %%
print(
    '{0:.3f}'.format(
        stats.mannwhitneyu(
            orders[
                np.logical_and(orders['group'] == 'A',
                    np.logical_not(orders['visitor_id'].isin(abnormal_users)),)
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['visitor_id'].isin(abnormal_users)),
                )
            ]['revenue'],
        )[1]
    )
)

print(
    "{0:.3f}".format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['visitor_id'].isin(abnormal_users)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['visitor_id'].isin(abnormal_users)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# 0.646
# -0.048

# %% [markdown]
# P-value равен 0.646, что больше 0.05, поэтому нельзя отвергнуть нулевую гипотезу, которая гласит что между группами нет статистически значимой разницы по среднему чеку. Без выбросов, группа A опередила группу B на 4% по среднему чеку. Похожий p-value  был получен в предыдущем тесте Манна-Уитни с неочищенными данными.
#
# Тест Манна-Уитни хорошо подходит для работы с данными, содержащими выбросы, так как ранжирование помогает нивелировать эффект выбросов, поэтому разница между полученными p-value небольшая.

# %% [markdown]
# ## Вывод:
#
# ## Проделанные работы:
#
# ### Часть 1:
#
#
# - Применен фреймворк ICE для приоритизации гипотез. Гипотезы отсортированы по убыванию приоритета.
# - Применен фреймворк RICE для приоритизации гипотез. Гипотезы отсортированы по убыванию приоритета.
# - Указано,  как изменилась приоритизация гипотез при применении RICE вместо ICE.
#
# ### Часть 2:
#
# Проанализирован A/B-тест:
#
# - Построен график кумулятивной выручки по группам.
# - Построен график кумулятивного среднего чека по группам.
# - Построен график относительного изменения кумулятивного среднего чека группы B к группе A.
# - Построен график кумулятивной конверсии по группам. Сделать выводы и предположения.
# - Построен график относительного изменения кумулятивной конверсии группы B к группе A.
# - Построен точечный график количества заказов по пользователям.
# - Посчитаны 95-й и 99-й перцентили количества заказов на пользователя. Выбрана граница для определения аномальных пользователей.
# - Построен точечный график стоимостей заказов.
# - Посчитаны 95-й и 99-й перцентили стоимости заказов. Выбрана граница для определения аномальных заказов.
# - Посчитана статистическую значимость различий в конверсии между группами по «сырым» данным.
# - Посчитана статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.
# - Посчитана статистическую значимость различий в конверсии между группами по «очищенным» данным.
# - Посчитана статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.
# - Принято решение по результатам теста

# %% [markdown]
# ### Решение по результатам теста

# %% [markdown]
# Было проведено несколько тестов для сравнения групп A и B:
# - на графике кумулятивной выручки группа B опережает групу A
# - на графике кумулятивного среднего чека группа B опережает групу A
# - также группа B опережает группу A на графиках относительного изменения кумулятивного среднего чека, кумулятивной конверсии и относительного изменения кумулятивной конверсии
#
# Были проведены тесты Манна-Уитни для сравнения конверсии и среднего чека между группами, по сырым и очищенным данным.
# Данные были очищены от выбросов по 95-му перцентилю (стоиомость) и 99-му перецентилю (количество заказов). Максимальное количество сделанных заказов составило 2, а максимальная стоимость - 26785 руб.
#
# Тест Манна-Уитни позволил определить, что  разница между группами по конверсиям статистически значима (такой результат был получен и по сырым, и по очищенным данным).
#
# Тест Манна-Уитни подтвердил, что по среднему чеку разницы между группами нет, а различие на графиках объясняется выбросами в стоимостях в группе B.
#
# Разница в результатах тестов по сырым и очищенным данным незначительна, так как тест Манна-Уитни сглаживает эффект от выбросов.
#
# Тест можно остановить, так как доказано, что разница между группами по конверсиям статистически значима в пользу группы B.
